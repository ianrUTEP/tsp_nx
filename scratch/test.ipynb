# %%
import matplotlib as mpl
import seaborn as sns
import colorsys
import ipywidgets

# %%
sns.color_palette('husl', 120)
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.9682106619380016, 0.4443375027194856, 0.5084338023648834),
#  (0.9686300672766753, 0.44742224854305507, 0.4785718248932325),
#  (0.9690582715067634, 0.45054639430228055, 0.44543304827786984),
#  (0.9694979754285514, 0.4537284387051496, 0.40783466214891867),
#  (0.9699521567340649, 0.4569882390259858, 0.36385324448493633),
#  (0.9704241569984234, 0.4603475375001678, 0.3099359864545268),
#  (0.9709177890861059, 0.46383058883897493, 0.23787151604055212),
#  (0.9542900080364486, 0.4779505175890752, 0.1963917622115608),
#  (0.9276092110470371, 0.4965370452365307, 0.1961198532721642),
#  (0.903599057664843, 0.511987276335809, 0.19588350060161624),
#  (0.8817338508705242, 0.5251217000399668, 0.19567509182499931),
#  (0.8616090647292522, 0.536495730113334, 0.19548899031476086),
#  (0.8429066603508676, 0.5465006439636432, 0.19532092722085148),
#  (0.8253715866849572, 0.5554211340334295, 0.1951676043226504),
# ...

# %%
# palette = sns.cubehelix_palette(reverse=True,n_colors=1000)

# %%
palette = sns.cubehelix_palette(as_cmap=True)
palette

# %%
def rgb_to_hex(r, g, b):
    return '#{:02x}{:02x}{:02x}'.format(int(r*255), int(g*255), int(b*255))

# %%
(r, g, b, a) = palette(10)
print(r, g, b, a)
str(rgb_to_hex(r, g, b))
# Out:
# 0.9186632490783021 0.7853883372186647 0.768648949707968 1.0
# '#eac8c4'

# %%
palette.N
# Out:
# (np.float64(0.60302658),
#  np.float64(0.78196121),
#  np.float64(0.56864272),
#  np.float64(1.0))

# %%
palette(100)
# Out:
# (np.float64(0.2720767),
#  np.float64(0.58584893),
#  np.float64(0.56092486),
#  np.float64(1.0))

# %%
minAtt
